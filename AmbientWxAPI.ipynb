# %%
# %pip install aioambient
# %pip install metpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 5.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 12.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 20.6 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 19.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 20.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 28.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 20.3 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 28.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 20.7 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import time
from aioambient import API
import asyncio
from datetime import date

# %%
api = API("2445ea8dd5434cb19d8eb95be7cf5609a0c3d62f0fa14563849b995ce150755d", "0a740280f9a14df3a16702cf4254b6c0c39d16849f3b48a88d73ad087c8c0cc1")

# %%
#api.get_devices()
devices == await api.get_devices()
device = devices[0]
#time.sleep(1)
#print(device)
#for i in device:
#    print(i)
# Out:
# macAddress
# lastData
# info

# %%
import pandas as pd

# %%
from datetime import datetime

# %%
cdat = await api.get_device_details("40:91:51:59:9E:F8")

print(cdat[0]['date'])
print(cdat[0])
#print(time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(int(str(cdat[0]['dateutc'])[:10]))))
#for i in cdat:
#    print(i)
print(type(cdat[0]))
print(len(cdat))
# Out:
# 2025-07-15T16:35:00.000Z
# {'dateutc': 1752597300000, 'tempf': 87.1, 'humidity': 63, 'windspeedmph': 0.67, 'windgustmph': 1.12, 'maxdailygust': 5.82, 'winddir': 96, 'winddir_avg10m': 88, 'uv': 7, 'solarradiation': 758.37, 'hourlyrainin': 0, 'eventrainin': 0, 'dailyrainin': 0, 'weeklyrainin': 0, 'monthlyrainin': 4.03, 'yearlyrainin': 17.68, 'battout': 1, 'tempinf': 70.7, 'humidityin': 55, 'baromrelin': 30.07, 'baromabsin': 29.111, 'battin': 1, 'feelsLike': 94.54, 'dewPoint': 72.94, 'feelsLikein': 70.1, 'dewPointin': 53.7, 'lastRain': '2025-07-12T02:37:00.000Z', 'date': '2025-07-15T16:35:00.000Z'}
# <class 'dict'>
# 288

# %%
df = pd.DataFrame(cdat)

# %%
#print(df.to_string())
print(df)
# Out:
#            dateutc  tempf  humidity  windspeedmph  windgustmph  maxdailygust  \
# 0    1752597300000   87.1        63          0.67         1.12          5.82
# 1    1752597000000   86.4        66          0.00         2.24          5.82
# 2    1752596700000   86.5        64          2.24         3.36          5.82
# 3    1752596400000   85.3        66          1.34         2.24          5.82
# 4    1752596100000   84.4        72          0.67         1.12          5.82
# ..             ...    ...       ...           ...          ...           ...
# 283  1752512400000   83.8        72          0.00         0.00          4.47
# 284  1752512100000   85.1        65          1.34         2.24          4.47
# 285  1752511800000   84.2        65          0.00         1.12          4.47
# 286  1752511500000   84.0        68          0.89         1.12          4.47
# 287  1752511200000   83.8        71          0.22         1.12          4.47
#
# ...

# %%
d = []
head = ['date','tempf', 'humidity', 'windspeedmph', 'windgustmph', 'maxdailygust', 'winddir', 'winddir_avg10m', 'uv', 'solarradiation', 'hourlyrainin','battout', 'feelsLike', 'dewPoint']
ndf = pd.DataFrame(d,columns=head)

# %%
#print(datetime.strptime(df['date'],'%Y-%m-%dT%H:%M:%S'),df['tempf'])
convdate = []
for i in df['date']:
    #print(i)
    print(datetime.strptime(i,'%Y-%m-%dT%H:%M:%S.%fZ'))
    convdate.append(datetime.strptime(i,'%Y-%m-%dT%H:%M:%S.%fZ'))

ndf['date'] = convdate
#ndf
# Out:
# 2025-07-15 16:35:00
# 2025-07-15 16:30:00
# 2025-07-15 16:25:00
# 2025-07-15 16:20:00
# 2025-07-15 16:15:00
# 2025-07-15 16:10:00
# 2025-07-15 16:05:00
# 2025-07-15 16:00:00
# 2025-07-15 15:55:00
# 2025-07-15 15:50:00
# 2025-07-15 15:45:00
# 2025-07-15 15:40:00
# 2025-07-15 15:35:00
# 2025-07-15 15:30:00
# 2025-07-15 15:25:00
# 2025-07-15 15:20:00
# 2025-07-15 15:15:00
# 2025-07-15 15:10:00
# 2025-07-15 15:05:00
# 2025-07-15 15:00:00
# 2025-07-15 14:55:00
# 2025-07-15 14:50:00
# 2025-07-15 14:45:00
# 2025-07-15 14:40:00
# 2025-07-15 14:35:00
# 2025-07-15 14:30:00
# 2025-07-15 14:25:00
# 2025-07-15 14:20:00
# 2025-07-15 14:15:00
# 2025-07-15 14:10:00
# 2025-07-15 14:05:00
# 2025-07-15 14:00:00
# 2025-07-15 13:55:00
# 2025-07-15 13:51:00
# 2025-07-15 13:45:00
# 2025-07-15 13:40:00
# 2025-07-15 13:35:00
# 2025-07-15 13:30:00
# 2025-07-15 13:25:00
# 2025-07-15 13:20:00
# 2025-07-15 13:15:00
# 2025-07-15 13:10:00
# 2025-07-15 13:05:00
# 2025-07-15 13:00:00
# 2025-07-15 12:55:00
# ...

# %%
new_df = df.drop('dateutc', axis=1)
print(new_df)
# Out:
#      tempf  humidity  windspeedmph  windgustmph  maxdailygust  winddir  \
# 0     87.1        63          0.67         1.12          5.82       96
# 1     86.4        66          0.00         2.24          5.82       43
# 2     86.5        64          2.24         3.36          5.82      113
# 3     85.3        66          1.34         2.24          5.82      125
# 4     84.4        72          0.67         1.12          5.82       99
# ..     ...       ...           ...          ...           ...      ...
# 283   83.8        72          0.00         0.00          4.47       82
# 284   85.1        65          1.34         2.24          4.47      131
# 285   84.2        65          0.00         1.12          4.47       98
# 286   84.0        68          0.89         1.12          4.47       95
# 287   83.8        71          0.22         1.12          4.47       97
#
#      winddir_avg10m  uv  solarradiation  hourlyrainin  ...  humidityin  \
# ...

# %%
#head = ['date','tempf', 'humidity', 'windspeedmph', 'windgustmph', 'maxdailygust', 'winddir', 'winddir_avg10m', 'uv', 'solarradiation', 'hourlyrainin','battout', 'feelsLike', 'dewPoint']
units = ['degF','percent','mi/hr','mi/hr','mi/hr','degrees','degrees','W/m^2','in','','degF','degF']
for i in units:
    print(i)
# Out:
# degF
# percent
# mi/hr
# mi/hr
# mi/hr
# degrees
# degrees
# W/m^2
# in
#
# degF
# degF

# %%
count=0
for i in df:
    dat=[]
    
    if i == 'dateutc' or i == 'date':
        continue
    else:
        print(count)
        print(units[count])
        count+=1
    #    for x in df[i]:
    #        print(x)
        #for a,b in zip(df[i],units):
            #print(a,'----',b)
            #dat.append(x)
    print('$$$$$$$$$$$$$$$$$$$$$$$$$$$')
    #print(df[i])
    #print(i)
    #print(dat)
    #ndf[i]=dat
    #
#print(df.keys()[1:-1])
# Out:
# 0
# degF
# $$$$$$$$$$$$$$$$$$$$$$$$$$$
# 1
# percent
# $$$$$$$$$$$$$$$$$$$$$$$$$$$
# 2
# mi/hr
# $$$$$$$$$$$$$$$$$$$$$$$$$$$
# 3
# mi/hr
# $$$$$$$$$$$$$$$$$$$$$$$$$$$
# 4
# mi/hr
# $$$$$$$$$$$$$$$$$$$$$$$$$$$
# 5
# degrees
# $$$$$$$$$$$$$$$$$$$$$$$$$$$
# 6
# degrees
# $$$$$$$$$$$$$$$$$$$$$$$$$$$
# 7
# W/m^2
# $$$$$$$$$$$$$$$$$$$$$$$$$$$
# 8
# in
# $$$$$$$$$$$$$$$$$$$$$$$$$$$
# 9
#
# $$$$$$$$$$$$$$$$$$$$$$$$$$$
# 10
# degF
# $$$$$$$$$$$$$$$$$$$$$$$$$$$
# 11
# degF
# $$$$$$$$$$$$$$$$$$$$$$$$$$$
# 12
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[127], line 9
#       7 else:
#       8     print(count)
# ----> 9     print(units[count])
#      10     count+=1
#      11 #    for x in df[i]:
#      12 #        print(x)
#      13     #for a,b in zip(df[i],units):
#      14         #print(a,'----',b)
#      15         #dat.append(x)
#
# IndexError: list index out of range

# %%
print(ndf)
# Out:
#                    date  tempf  humidity  windspeedmph  windgustmph  \
# 0   2025-07-15 16:35:00   87.1        63          0.67         1.12
# 1   2025-07-15 16:30:00   86.4        66          0.00         2.24
# 2   2025-07-15 16:25:00   86.5        64          2.24         3.36
# 3   2025-07-15 16:20:00   85.3        66          1.34         2.24
# 4   2025-07-15 16:15:00   84.4        72          0.67         1.12
# ..                  ...    ...       ...           ...          ...
# 283 2025-07-14 17:00:00   83.8        72          0.00         0.00
# 284 2025-07-14 16:55:00   85.1        65          1.34         2.24
# 285 2025-07-14 16:50:00   84.2        65          0.00         1.12
# 286 2025-07-14 16:45:00   84.0        68          0.89         1.12
# 287 2025-07-14 16:40:00   83.8        71          0.22         1.12
#
#      maxdailygust  winddir  winddir_avg10m  uv  solarradiation  ...  \
# 0            5.82       96              88   7          758.37  ...
# ...

# %%
pastdat = await api.get_device_details("40:91:51:59:9E:F8", end_date=date(datetime.today().year, datetime.today().month, datetime.today().day))

#print(pastdat)
for i in pastdat:
    formatted_time = time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(int(str(i['dateutc'])[:10])))
    #formatted_time = time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(i['dateutc']))
    print(formatted_time)
    #utc_datetime = datetime.utcfromtimestamp(int(i['dateutc']))
    #print(f"Epoch timestamp: {epoch_timestamp}")
    #print(f"UTC Datetime: {utc_datetime}")
    #print(i['dateutc'])
# Out:
# 2025-07-15 00:00:00
# 2025-07-14 23:55:00
# 2025-07-14 23:50:00
# 2025-07-14 23:45:00
# 2025-07-14 23:40:00
# 2025-07-14 23:35:00
# 2025-07-14 23:30:00
# 2025-07-14 23:25:00
# 2025-07-14 23:20:00
# 2025-07-14 23:15:00
# 2025-07-14 23:10:00
# 2025-07-14 23:05:00
# 2025-07-14 23:00:00
# 2025-07-14 22:55:00
# 2025-07-14 22:50:00
# 2025-07-14 22:45:00
# 2025-07-14 22:40:00
# 2025-07-14 22:35:00
# 2025-07-14 22:30:00
# 2025-07-14 22:25:00
# 2025-07-14 22:20:00
# 2025-07-14 22:15:00
# 2025-07-14 22:10:00
# 2025-07-14 22:05:00
# 2025-07-14 22:00:00
# 2025-07-14 21:55:00
# 2025-07-14 21:50:00
# 2025-07-14 21:45:00
# 2025-07-14 21:40:00
# 2025-07-14 21:35:00
# 2025-07-14 21:30:00
# 2025-07-14 21:25:00
# 2025-07-14 21:20:00
# 2025-07-14 21:15:00
# 2025-07-14 21:10:00
# 2025-07-14 21:05:00
# 2025-07-14 21:00:00
# 2025-07-14 20:55:00
# 2025-07-14 20:50:00
# 2025-07-14 20:45:00
# 2025-07-14 20:40:00
# 2025-07-14 20:36:00
# 2025-07-14 20:30:00
# 2025-07-14 20:25:00
# 2025-07-14 20:20:00
# ...

# %%
def add_labels(x, y):
    for i in range(len(x)):
        fig.text(i, y[i], y[i], ha='center')


fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=4,figsize=(8, 8))
ax1.bar(hours, temp.to('degF'), color='tab:red',align='center', width=2.5)
ax1.bar(hours, tdew.to('degF'), color='tab:green',align='center', width=1.5)
ax2.bar(hours, qpf, width=3)
#ax3.bar(hours, windgst.to('kt'), width=3)
#add_labels(hours, windgst.to('kt'))
bar_container = ax3.bar(hours, w, width=3)
ax3.bar_label(bar_container, label_type='edge',padding=1)
ax3.set_ylabel("Wing Gusts (kts)")#,fmt='{:,.0f}')
#ax3.bar_label(p, label_type='center')
#ax3.bar_label(windgst.to('kt'), label_type='center', padding=5, fmt='%.1f', rotation=45)
#ax3.text(hours, windgst.to('kt'), windgst.to('kt'), ha='center')
#ax3.barbs(hours,windgst,uwind,vwind)
ax4.barbs(hours,cntr,uwind,vwind,np.sqrt(uwind ** 2 + vwind ** 2),pivot='middle',sizes=dict(emptybarb=0.1, spacing=0.2, height=0.3),length=6,)
fig.tight_layout()
